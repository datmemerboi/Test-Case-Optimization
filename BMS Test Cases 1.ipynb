# %%
# import numpy as np
import pandas as pd

# %%
dfile = pd.read_csv("BMS Test Cases 1.csv")
dfile
# Out:
#             TEST ID                                 TEST CASE PRE-CONDITIONS  \
# 0          LOAD_001  Test Page load functionality through URL           None
# 1          LOAD_002          Test Page Reload without crashes           None
# 2          LOAD_003  Test 404 Error for Invalid URL in domain           None
# 3   SELECT_CITY_001              Test City Choice using Icons       LOAD_001
# 4   SELECT_CITY_002         Test Search City using Search Bar       LOAD_001
# ..              ...                                       ...            ...
# 85      SESSION_001            Check display of Session Timer   PAY_INIT_001
# 86      SESSION_002                      Test Session Timeout   PAY_INIT_001
# 87      SESSION_003          Check display of Timeout Message    SESSION_002
# 88      SESSION_004          Test Start Again button function    SESSION_003
# 89      SESSION_005                          Test Timer reset    SESSION_001
#
#                          TEST STEPS PRECEDENCE  EXPECTED RESULT  \
# 0                 Enter Invalid URL          H              NaN
# 1                               NaN          H              NaN
# 2                               NaN        NaN              NaN
# 3   Choose city from name and icons        NaN              NaN
# 4         Choose city by Search Bar        NaN              NaN
# ..                              ...        ...              ...
# 85                              NaN        NaN              NaN
# 86                              NaN        NaN              NaN
# 87                              NaN        NaN              NaN
# 88                              NaN        NaN              NaN
# 89               No reset on reload        NaN              NaN
#
#     ACTUAL RESULT  PASS/FAIL
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN
# ..            ...        ...
# 85            NaN        NaN
# 86            NaN        NaN
# 87            NaN        NaN
# 88            NaN        NaN
# 89            NaN        NaN
#
# [90 rows x 8 columns]

# %%
dfile = dfile.drop(['TEST STEPS',"EXPECTED RESULT", 'ACTUAL RESULT', 'PASS/FAIL'], axis=1)
dfile
# Out:
#             TEST ID                                 TEST CASE PRE-CONDITIONS  \
# 0          LOAD_001  Test Page load functionality through URL           None
# 1          LOAD_002          Test Page Reload without crashes           None
# 2          LOAD_003  Test 404 Error for Invalid URL in domain           None
# 3   SELECT_CITY_001              Test City Choice using Icons       LOAD_001
# 4   SELECT_CITY_002         Test Search City using Search Bar       LOAD_001
# ..              ...                                       ...            ...
# 85      SESSION_001            Check display of Session Timer   PAY_INIT_001
# 86      SESSION_002                      Test Session Timeout   PAY_INIT_001
# 87      SESSION_003          Check display of Timeout Message    SESSION_002
# 88      SESSION_004          Test Start Again button function    SESSION_003
# 89      SESSION_005                          Test Timer reset    SESSION_001
#
#    PRECEDENCE
# 0           H
# 1           H
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 85        NaN
# 86        NaN
# 87        NaN
# 88        NaN
# 89        NaN
#
# [90 rows x 4 columns]

# %%
Priority = [0]* dfile['TEST ID'].count()
dfile['PRIORITY'] = Priority
dfile
# Out:
#             TEST ID                                 TEST CASE PRE-CONDITIONS  \
# 0          LOAD_001  Test Page load functionality through URL           None
# 1          LOAD_002          Test Page Reload without crashes           None
# 2          LOAD_003  Test 404 Error for Invalid URL in domain           None
# 3   SELECT_CITY_001              Test City Choice using Icons       LOAD_001
# 4   SELECT_CITY_002         Test Search City using Search Bar       LOAD_001
# ..              ...                                       ...            ...
# 85      SESSION_001            Check display of Session Timer   PAY_INIT_001
# 86      SESSION_002                      Test Session Timeout   PAY_INIT_001
# 87      SESSION_003          Check display of Timeout Message    SESSION_002
# 88      SESSION_004          Test Start Again button function    SESSION_003
# 89      SESSION_005                          Test Timer reset    SESSION_001
#
#    PRECEDENCE  PRIORITY
# 0           H         0
# 1           H         0
# 2         NaN         0
# 3         NaN         0
# 4         NaN         0
# ..        ...       ...
# 85        NaN         0
# 86        NaN         0
# 87        NaN         0
# 88        NaN         0
# 89        NaN         0
#
# [90 rows x 5 columns]

# %%
for i in dfile['PRE-CONDITIONS']:
    if (i in dfile['TEST ID'].values):
        print("Increase weightage of: ",i, end="\t")
        x = dfile.loc[dfile['TEST ID'] == i].index.values[0]
        print(" at row: ",x, end='\n')
# Out:
# Increase weightage of:  LOAD_001	 at row:  0
# Increase weightage of:  LOAD_001	 at row:  0
# Increase weightage of:  LOAD_001	 at row:  0
# Increase weightage of:  LOAD_001	 at row:  0
# Increase weightage of:  SELECT_CITY_001	 at row:  3
# Increase weightage of:  SELECT_CITY_002	 at row:  4
# Increase weightage of:  SELECT_CITY_003	 at row:  5
# Increase weightage of:  HOME_001	 at row:  6
# Increase weightage of:  HOME_001	 at row:  6
# Increase weightage of:  SIGN_IN_001	 at row:  11
# Increase weightage of:  SIGN_IN_001	 at row:  11
# Increase weightage of:  SIGN_IN_001	 at row:  11
# Increase weightage of:  SIGN_UP_001	 at row:  14
# Increase weightage of:  SIGN_UP_001	 at row:  14
# Increase weightage of:  SIGN_IN_001	 at row:  11
# Increase weightage of:  HOME_001	 at row:  6
# Increase weightage of:  SEARCHBAR_001	 at row:  18
# Increase weightage of:  SEARCHBAR_001	 at row:  18
# Increase weightage of:  HOME_001	 at row:  6
# Increase weightage of:  CATEGORY_001	 at row:  21
# Increase weightage of:  SEARCHBAR_001	 at row:  18
# Increase weightage of:  CATEGORY_001	 at row:  21
# Increase weightage of:  SEARCHBAR_001	 at row:  18
# Increase weightage of:  CATEGORY_001	 at row:  21
# Increase weightage of:  RECOMMEND_001	 at row:  25
# Increase weightage of:  MOVIE_LOAD_001	 at row:  28
# Increase weightage of:  MOVIE_LOAD_001	 at row:  28
# Increase weightage of:  MOVIE_LOAD_001	 at row:  28
# Increase weightage of:  MOVIE_LOAD_001	 at row:  28
# Increase weightage of:  BOOK_LOAD_001	 at row:  33
# Increase weightage of:  BOOK_LOAD_001	 at row:  33
# Increase weightage of:  SHOWTIME_001	 at row:  35
# Increase weightage of:  SHOWTIME_002	 at row:  36
# Increase weightage of:  SEATS_001	 at row:  37
# Increase weightage of:  SEATS_002	 at row:  38
# Increase weightage of:  SEATS_001	 at row:  37
# Increase weightage of:  SEATS_003	 at row:  39
# Increase weightage of:  PAY_BUTTON_001	 at row:  41
# Increase weightage of:  PAY_BUTTON_002	 at row:  42
# Increase weightage of:  PAY_INIT_001	 at row:  43
# Increase weightage of:  PAY_INIT_001	 at row:  43
# Increase weightage of:  PAY_INIT_001	 at row:  43
# Increase weightage of:  PAY_INIT_001	 at row:  43
# Increase weightage of:  PAY_INIT_001	 at row:  43
# Increase weightage of:  PAY_INIT_001	 at row:  43
# Increase weightage of:  PAY_INIT_001	 at row:  43
# Increase weightage of:  PAYMENT_OPT_003	 at row:  50
# Increase weightage of:  PAYMENT_OPT_003	 at row:  50
# Increase weightage of:  PAYMENT_OPT_003	 at row:  50
# Increase weightage of:  PAYMENT_OPT_003	 at row:  50
# Increase weightage of:  PAYMENT_OPT_003	 at row:  50
# Increase weightage of:  PAYMENT_OPT_003	 at row:  50
# Increase weightage of:  PAYMENT_OPT_003	 at row:  50
# Increase weightage of:  PAYMENT_OPT_003	 at row:  50
# Increase weightage of:  MOB_WALLET_002	 at row:  58
# Increase weightage of:  MOB_WALLET_002	 at row:  58
# Increase weightage of:  PAYMENT_OPT_003	 at row:  50
# Increase weightage of:  PAYMENT_OPT_003	 at row:  50
# Increase weightage of:  VOUCHER_003	 at row:  63
# Increase weightage of:  PAYMENT_OPT_003	 at row:  50
# Increase weightage of:  UPI_001	 at row:  64
# Increase weightage of:  UPI_001	 at row:  64
# Increase weightage of:  UPI_002	 at row:  65
# Increase weightage of:  UPI_002	 at row:  65
# Increase weightage of:  UPI_002	 at row:  65
# Increase weightage of:  UPI_002	 at row:  65
# Increase weightage of:  PAY_BUTTON_002	 at row:  42
# Increase weightage of:  PAY_INIT_002	 at row:  71
# Increase weightage of:  PAY_INIT_002	 at row:  71
# Increase weightage of:  PAY_PORTAL_002	 at row:  73
# Increase weightage of:  PAY_PORTAL_002	 at row:  73
# Increase weightage of:  PAY_PORTAL_003	 at row:  74
# Increase weightage of:  CONFIRM_001	 at row:  76
# Increase weightage of:  CONFIRM_001	 at row:  76
# Increase weightage of:  CONFIRM_001	 at row:  76
# Increase weightage of:  CONFIRM_001	 at row:  76
# Increase weightage of:  CONFIRM_001	 at row:  76
# Increase weightage of:  CONFIRM_001	 at row:  76
# Increase weightage of:  PAY_PORTAL_002	 at row:  73
# Increase weightage of:  PAY_PORTAL_002	 at row:  73
# Increase weightage of:  PAY_INIT_001	 at row:  43
# Increase weightage of:  PAY_INIT_001	 at row:  43
# Increase weightage of:  SESSION_002	 at row:  86
# Increase weightage of:  SESSION_003	 at row:  87
# Increase weightage of:  SESSION_001	 at row:  85
