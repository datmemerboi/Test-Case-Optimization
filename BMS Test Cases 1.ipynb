# %%
# import numpy as np
import pandas as pd

# %%
dfile = pd.read_csv("BMS Test Cases 1.csv")
dfile
# Out:
#             TEST ID                                  TEST CASE  \
# 0          LOAD_001                               Load Website
# 1          LOAD_001                               Load Website
# 2          LOAD_001                               Load Website
# 3               NaN                                        NaN
# 4   SELECT_CITY_001                                Choose City
# 5   SELECT_CITY_002                                Choose City
# 6   SELECT_CITY_003                                Choose City
# 7   SELECT_CITY_003                                Choose City
# 8               NaN                                        NaN
# 9          HOME_001                          Land on Home Page
# 10         HOME_002                      Menu Bar on Home Page
# 11         HOME_002                      Menu Bar on Home Page
# 12         HOME_002                      Menu Bar on Home Page
# 13         HOME_003                                Change City
# ...

# %%
dfile = dfile.drop(["EXPECTED RESULT", 'ACTUAL RESULT', 'PASS/FAIL'], axis=1)
dfile
# Out:
#             TEST ID                                  TEST CASE  \
# 0          LOAD_001                               Load Website
# 1          LOAD_001                               Load Website
# 2          LOAD_001                               Load Website
# 3               NaN                                        NaN
# 4   SELECT_CITY_001                                Choose City
# 5   SELECT_CITY_002                                Choose City
# 6   SELECT_CITY_003                                Choose City
# 7   SELECT_CITY_003                                Choose City
# 8               NaN                                        NaN
# 9          HOME_001                          Land on Home Page
# 10         HOME_002                      Menu Bar on Home Page
# 11         HOME_002                      Menu Bar on Home Page
# 12         HOME_002                      Menu Bar on Home Page
# 13         HOME_003                                Change City
# ...

# %%
dfile = dfile.drop([3,8,20,24])
dfile.reset_index(drop=True)
# Out:
#             TEST ID                                  TEST CASE  \
# 0          LOAD_001                               Load Website
# 1          LOAD_001                               Load Website
# 2          LOAD_001                               Load Website
# 3   SELECT_CITY_001                                Choose City
# 4   SELECT_CITY_002                                Choose City
# 5   SELECT_CITY_003                                Choose City
# 6   SELECT_CITY_003                                Choose City
# 7          HOME_001                          Land on Home Page
# 8          HOME_002                      Menu Bar on Home Page
# 9          HOME_002                      Menu Bar on Home Page
# 10         HOME_002                      Menu Bar on Home Page
# 11         HOME_003                                Change City
# 12         HOME_003                                Change City
# 13         HOME_005                            Change Language
# ...

# %%
Priority = [0]* dfile['TEST ID'].count()
dfile['PRIORITY'] = Priority
dfile
# Out:
#             TEST ID                                  TEST CASE  \
# 0          LOAD_001                               Load Website
# 1          LOAD_001                               Load Website
# 2          LOAD_001                               Load Website
# 4   SELECT_CITY_001                                Choose City
# 5   SELECT_CITY_002                                Choose City
# 6   SELECT_CITY_003                                Choose City
# 7   SELECT_CITY_003                                Choose City
# 9          HOME_001                          Land on Home Page
# 10         HOME_002                      Menu Bar on Home Page
# 11         HOME_002                      Menu Bar on Home Page
# 12         HOME_002                      Menu Bar on Home Page
# 13         HOME_003                                Change City
# 14         HOME_003                                Change City
# 15         HOME_005                            Change Language
# ...

# %%
for i in dfile['PRE-CONDITIONS']:
    if i in dfile['TEST ID'].values:
        x = dfile.loc[dfile['TEST ID'] == i].index
        print(x)
# Out:
# Int64Index([0, 1, 2], dtype='int64')
# Int64Index([0, 1, 2], dtype='int64')
# Int64Index([0, 1, 2], dtype='int64')
# Int64Index([0, 1, 2], dtype='int64')
# Int64Index([4], dtype='int64')
# Int64Index([9], dtype='int64')
# Int64Index([9], dtype='int64')
# Int64Index([9], dtype='int64')
# Int64Index([9], dtype='int64')
# Int64Index([9], dtype='int64')
# Int64Index([9], dtype='int64')
# Int64Index([9], dtype='int64')
# Int64Index([9], dtype='int64')
# Int64Index([9], dtype='int64')
# Int64Index([9], dtype='int64')
# Int64Index([0, 1, 2], dtype='int64')
# Int64Index([0, 1, 2], dtype='int64')
# Int64Index([0, 1, 2], dtype='int64')
# Int64Index([0, 1, 2], dtype='int64')
# Int64Index([0, 1, 2], dtype='int64')
# Int64Index([0, 1, 2], dtype='int64')

# %% [markdown]
# ### Dataset has an issue with repetitive TEST IDs. Will have to alter them before proceeding.
